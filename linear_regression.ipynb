# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset=pd.read_csv('/content/Laptop_price.csv')
dataset.head()
# Out:
#     Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight  \
# 0    Asus         3.830296        16               512    11.185147  2.641094
# 1    Acer         2.912833         4              1000    11.311372  3.260012
# 2  Lenovo         3.241627         4               256    11.853023  2.029061
# 3    Acer         3.806248        16               512    12.280360  4.573865
# 4    Acer         3.268097        32              1000    14.990877  4.193472
#
#           Price
# 0  17395.093065
# 1  31607.605919
# 2   9291.023542
# 3  17436.728334
# 4  32917.990718

# %%
dataset.isnull().sum()
# Out:
# Brand               0
# Processor_Speed     0
# RAM_Size            0
# Storage_Capacity    0
# Screen_Size         0
# Weight              0
# Price               0
# dtype: int64

# %%
#simple linear regression
X=dataset[['RAM_Size']]
y=dataset['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= model.predict(X_test)

# %%
print("Simple linear regression R² Score:", model.score(X_test, y_test))
# Out:
# Simple linear regression R² Score: -0.0026251761078115443

# %%
plt.scatter(X_test, y_test, color='blue', label='Actual Price')
plt.plot(X_test, y_pred, color='red', label='Predicted Price')
plt.xlabel("RAM (GB)")
plt.ylabel("Price")
plt.title("Laptop Price Prediction according to RAM")
plt.legend()
plt.show()

# %%
#multiple linear regression
X_multi = dataset[['RAM_Size', 'Storage_Capacity']]   # Multiple features
y = dataset['Price']

# %%
X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(X_multi, y, test_size=0.2, random_state=1)
model_m = LinearRegression()
model_m.fit(X_train_m, y_train_m)
# Out:
# LinearRegression()

# %%
y_pred_m = model_m.predict(X_test_m)
print("Multiple Linear Regression R² Score:", model_m.score(X_test_m, y_test_m))
# Out:
# Multiple Linear Regression R² Score: 0.9994080069814286

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='green', edgecolors='k')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted Prices (Multiple Linear Regression)')
plt.grid(True)
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red', linewidth=2)
plt.show()
